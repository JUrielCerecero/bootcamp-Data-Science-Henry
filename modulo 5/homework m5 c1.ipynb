# %% [markdown]
# # Homework
#
# Desde la gerencia de ventas nos comentan que es necesario aumentar el volumen de facturación y cobertura de regiones ( tener clientes en la mayor cantidad posible de zonas) como también evitar la pérdida de clientes, hoy por hoy se manejan con un Excel que alguien armo en algún momento, pero no confían en esa data para seguir este nuevo objetivo, de manera tal que no se conoce realmente el estado de situación actual. Por lo tanto como departamento de data analytics tenemos que presentarles una propuesta basadas en datos para acompañar este proceso de negocio.
# En base al modelo de datos utilizado en M3 generar una un propuesta analítico de cada tipo según lo visto en clase:
#
# a) Descriptivo
#
# b) Dashboard
#
# c) Predictivo
#
# d) Prescriptivo

# %%
"""descriptivo: 
    - analizar la cantidad de clientes que hay actualmente en total
    - cuantos clientes hay por region
    - cuales son las regiones que mas clientes tienen y cuales menos
    - volument totalde facturacion actual, y volumen de facturacion por regiones
    - cuantos clientes activos hay en total y en cada region asi como su volumen de facturacion a la fecha

Dashboard:
    -analizar vlolumen de facturacion actual y de los ulitmos dos años por mes, tanto a nivel general como por region
    -cantidad de clientes activos por es de los ultimos dos años vs la cantidad de clientes registrados en la base de datos
    -analizar sucesos que han ocurrido en fechas donde ha habido mayor volumen de facturacion para analizar posibles detonantes de ventas

precitivo:
    -basado en las fechas con mayor volumen de ventas, predecir el volumen de ventas e proximas fechas y preveer como afrontarlas 
    y como hacer que estas puedean aumentar aun mas
    
prescriptivo:
    - implementar en los modulos de prediccion las estrategias para auamentar la ventas, y basado en los datos, ver la posiblidad de que
    estas ayuden a lograr el objetivo, o buscar aletrnativas viables,basado en los datos previos

# %% [markdown]
# Relaciona cada situación con algún tipo de gráfico:
#
# a) Velocidad de frenado promedio de 5 modelos distintos de vehículos.
#
# Gráfico de columnas:
#
# Eje x = modelos de vehículos.
#
# Eje y = Velocidad promedio de frenado.
#
# b) Costo de una llamada por segundos.
#
# Gráfico de líneas: Eje x = Csoto de la llamada.
#
# Eje y = Segundos de duración.
#
# c) El recorrido del equipo de ventas de una distribuidora con 4 paradas y las sumas vendidas en cada una.
#
# Mapa georeferenciado:
#
# Latiud y longitud de cada parada.
#
# Importe de ventas totales en cada punto.
#
# d) Cantidad de edificios y casas que conforman un barrio. Gráfico circular:
#
# Dos categorias.

# %% [markdown]
# Cantidad total por categoría.
#
# El siguiente gráfico representa el movimiento vehículo desde un punto. Interprétala y responde a las siguientes preguntas:
# ![image.png](attachment:image.png)
#
# a) ¿Cuánto tiempo ha estado andando?
#
# 14 min total, 12 sin la parada
#
# b) ¿Hasta que distancia máxima del recorrido pudo realizar?
#
# 80 m
#
# c) ¿Ha hecho alguna parada?
#
# si
#
# d) ¿Que sucede luego del pico de mts recorrido?
#
# regresa al punto de origen
#
# e) ¿Cuantos metros recorrio en total?
#
# 160 m

# %% [markdown]
# Ejercicio2
#
# Se decide presentar el volumen de ventas de 5 productos correspondientes a una distribuidora de alimentos. Los productos van de
# A = 100 un., B = 95 un., C =90 un., D = 88 un., E = 105 un.
#
# a) ¿Que gráfico utilizaría?.
#
# grafico de barras
# x=diferentes productos
# y= volumen de ventas
#
# b) ¿Sería correcto utilizar un gráfico de lineas? ¿Por qué?.
#
# no, no ayuda a visualizar laas diferencias de ventas
#
# c) ¿Sería correcto utilizar un gráfico circular? ¿Por qué?.
#
# si, un grfico de pay ayuaria tambien a visualizar las diferencias, pero no seria tan claro como uno de barras

# %% [markdown]
# Se presenta el siguiente gráfico.
#
# ![image.png](attachment:image.png)
#
# a) ¿Es correcta su utilización?
#
# no, porque ese tipo de graficas es para representar las disitintas partes de un todo
#
# b) ¿Que inconveniente presenta a la hora de reconocer patrones?
#
# ahi se usan diferentes opiniones de un productos, pero es relativo el valor de cada opinion porque no sen identifica cual es bueno en si o cual es malo, no nos ayuda a visualizar las diferencias de cantidad entre cada opinion
#
# c) ¿Qué otros tipos de gráficos utilizaría?
#
# uno de barras o uno de densidad
#
# d) ¿Que tipo de tematicas estarían relacionadas a la variable presentada?
#
# las opiniones de la gente respecto a un producto, las cuales se pueden tratar de darle una escala de valores, sin embargo estos son muy subjetivos, cada persona tiene una percepcion disitinta de como califica un producto, pero esto ayuda a dar una idea de la percepcion de un producto o servicio
